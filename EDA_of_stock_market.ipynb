# %% [markdown]
# <a href="https://colab.research.google.com/github/Rezamoghadam8810/Algorithmic_trading_tutorial/blob/main/EDA_of_stock_market.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use('ggplot')

# %%
pd.read_csv('/content/multi_assets.csv',header=[0,1],index_col=0, parse_dates=[0])
# Out:
# Price         Close                                                    \
# Ticker           BA    BTC-USD EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01 108.4067   383.6150   1.2628 1214.6000  39.0886 16804.7109
# 2014-10-02 107.9719   375.0720   1.2624 1214.2000  38.9694 16801.0508
# 2014-10-03 109.8762   359.5120   1.2671 1192.2000  39.2504 17009.6895
# 2014-10-04      NaN   328.8660      NaN       NaN      NaN        NaN
# 2014-10-05      NaN   320.5100      NaN       NaN      NaN        NaN
# ...             ...        ...      ...       ...      ...        ...
# 2021-05-26 241.3700 39294.1992   1.2249 1901.3000 243.7286 34323.0508
# 2021-05-27 250.7000 38436.9688   1.2193 1895.7000 241.6159 34464.6406
# 2021-05-28 247.0200 35697.6055   1.2193 1902.5000 241.9745 34529.4492
# 2021-05-29      NaN 34616.0664      NaN       NaN      NaN        NaN
# 2021-05-30      NaN 35678.1289      NaN       NaN      NaN        NaN
#
# ...

# %%
df=pd.read_csv('/content/multi_assets.csv',header=[0,1],index_col=0, parse_dates=[0])
df
# Out:
# Price         Close                                                    \
# Ticker           BA    BTC-USD EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01 108.4067   383.6150   1.2628 1214.6000  39.0886 16804.7109
# 2014-10-02 107.9719   375.0720   1.2624 1214.2000  38.9694 16801.0508
# 2014-10-03 109.8762   359.5120   1.2671 1192.2000  39.2504 17009.6895
# 2014-10-04      NaN   328.8660      NaN       NaN      NaN        NaN
# 2014-10-05      NaN   320.5100      NaN       NaN      NaN        NaN
# ...             ...        ...      ...       ...      ...        ...
# 2021-05-26 241.3700 39294.1992   1.2249 1901.3000 243.7286 34323.0508
# 2021-05-27 250.7000 38436.9688   1.2193 1895.7000 241.6159 34464.6406
# 2021-05-28 247.0200 35697.6055   1.2193 1902.5000 241.9745 34529.4492
# 2021-05-29      NaN 34616.0664      NaN       NaN      NaN        NaN
# 2021-05-30      NaN 35678.1289      NaN       NaN      NaN        NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2434 entries, 2014-10-01 to 2021-05-30
# Data columns (total 30 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   (Close, BA)         1677 non-null   float64
#  1   (Close, BTC-USD)    2434 non-null   float64
#  2   (Close, EURUSD=X)   1735 non-null   float64
#  3   (Close, GC=F)       1674 non-null   float64
#  4   (Close, MSFT)       1677 non-null   float64
#  5   (Close, ^DJI)       1677 non-null   float64
#  6   (High, BA)          1677 non-null   float64
#  7   (High, BTC-USD)     2434 non-null   float64
#  8   (High, EURUSD=X)    1735 non-null   float64
#  9   (High, GC=F)        1674 non-null   float64
#  10  (High, MSFT)        1677 non-null   float64
#  11  (High, ^DJI)        1677 non-null   float64
#  12  (Low, BA)           1677 non-null   float64
#  13  (Low, BTC-USD)      2434 non-null   float64
#  14  (Low, EURUSD=X)     1735 non-null   float64
# ...

# %%
df.Close
# Out:
# Ticker           BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01 108.4067   383.6150    1.2628 1214.6000  39.0886 16804.7109
# 2014-10-02 107.9719   375.0720    1.2624 1214.2000  38.9694 16801.0508
# 2014-10-03 109.8762   359.5120    1.2671 1192.2000  39.2504 17009.6895
# 2014-10-04      NaN   328.8660       NaN       NaN      NaN        NaN
# 2014-10-05      NaN   320.5100       NaN       NaN      NaN        NaN
# ...             ...        ...       ...       ...      ...        ...
# 2021-05-26 241.3700 39294.1992    1.2249 1901.3000 243.7286 34323.0508
# 2021-05-27 250.7000 38436.9688    1.2193 1895.7000 241.6159 34464.6406
# 2021-05-28 247.0200 35697.6055    1.2193 1902.5000 241.9745 34529.4492
# 2021-05-29      NaN 34616.0664       NaN       NaN      NaN        NaN
# 2021-05-30      NaN 35678.1289       NaN       NaN      NaN        NaN
#
# [2434 rows x 6 columns]

# %%
df.Close.BA
# Out:
# Date
# 2014-10-01   108.4067
# 2014-10-02   107.9719
# 2014-10-03   109.8762
# 2014-10-04        NaN
# 2014-10-05        NaN
#                ...
# 2021-05-26   241.3700
# 2021-05-27   250.7000
# 2021-05-28   247.0200
# 2021-05-29        NaN
# 2021-05-30        NaN
# Name: BA, Length: 2434, dtype: float64

# %%
df.loc[:,("Close","BA")]
# Out:
# Date
# 2014-10-01   108.4067
# 2014-10-02   107.9719
# 2014-10-03   109.8762
# 2014-10-04        NaN
# 2014-10-05        NaN
#                ...
# 2021-05-26   241.3700
# 2021-05-27   250.7000
# 2021-05-28   247.0200
# 2021-05-29        NaN
# 2021-05-30        NaN
# Name: (Close, BA), Length: 2434, dtype: float64

# %%
df.loc["2015-01-07"]
# Out:
# Price   Ticker
# Close   BA              113.2724
#         BTC-USD         294.3370
#         EURUSD=X          1.1875
#         GC=F           1210.6000
#         MSFT             39.6179
#         ^DJI          17584.5195
# High    BA              113.6747
#         BTC-USD         298.7540
#         EURUSD=X          1.1900
#         GC=F           1219.2000
#         MSFT             39.8151
#         ^DJI          17597.0801
# Low     BA              112.5814
#         BTC-USD         283.0790
#         EURUSD=X          1.1804
#         GC=F           1210.6000
#         MSFT             38.9838
#         ^DJI          17374.7793
# Open    BA              112.5989
#         BTC-USD         286.0770
#         EURUSD=X          1.1875
#         GC=F           1219.2000
#         MSFT             39.4037
#         ^DJI          17374.7793
# Volume  BA          3573200.0000
#         BTC-USD    24866800.0000
#         EURUSD=X          0.0000
#         GC=F             29.0000
# ...

# %%
df.loc["2015"]
# Out:
# Price         Close                                                    High  \
# Ticker           BA  BTC-USD EURUSD=X      GC=F    MSFT       ^DJI       BA
# Date
# 2015-01-01      NaN 314.2490   1.2099       NaN     NaN        NaN      NaN
# 2015-01-02 113.6572 315.0320   1.2089 1186.0000 40.0721 17832.9902 115.3102
# 2015-01-03      NaN 281.0820      NaN       NaN     NaN        NaN      NaN
# 2015-01-04      NaN 264.1950      NaN       NaN     NaN        NaN      NaN
# 2015-01-05 112.8700 274.4740   1.1946 1203.9000 39.7036 17501.6504 113.6310
# ...             ...      ...      ...       ...     ...        ...      ...
# 2015-12-27      NaN 422.8230      NaN       NaN     NaN        NaN      NaN
# 2015-12-28 129.6283 422.2790   1.0966 1070.5000 49.2530 17528.2695 129.7449
# 2015-12-29 132.1484 432.9830   1.0975 1077.5000 49.7812 17720.9805 132.3367
# 2015-12-30 131.3054 426.6200   1.0928 1060.1000 49.5700 17603.8691 132.7314
# ...

# %%
df.loc["2020-06":,("Close","BA")]
# Out:
# Date
# 2020-06-01   151.3900
# 2020-06-02   153.3100
# 2020-06-03   173.1600
# 2020-06-04   184.3000
# 2020-06-05   205.4300
#                ...
# 2021-05-26   241.3700
# 2021-05-27   250.7000
# 2021-05-28   247.0200
# 2021-05-29        NaN
# 2021-05-30        NaN
# Name: (Close, BA), Length: 364, dtype: float64

# %%
df=df.swaplevel(axis="columns").sort_index(axis="columns")
df
# Out:
# Ticker           BA                                             BTC-USD  \
# Price         Close     High      Low     Open        Volume      Close
# Date
# 2014-10-01 108.4067 110.7545 108.0936 110.7545  5265200.0000   383.6150
# 2014-10-02 107.9719 109.1719 107.6849 108.1719  3204500.0000   375.0720
# 2014-10-03 109.8762 110.3197 108.3980 108.3980  3075900.0000   359.5120
# 2014-10-04      NaN      NaN      NaN      NaN           NaN   328.8660
# 2014-10-05      NaN      NaN      NaN      NaN           NaN   320.5100
# ...             ...      ...      ...      ...           ...        ...
# 2021-05-26 241.3700 242.4900 239.8700 241.7000  7240200.0000 39294.1992
# 2021-05-27 250.7000 252.6000 247.1900 248.1100 18404400.0000 38436.9688
# 2021-05-28 247.0200 248.9800 245.3700 247.4800 11197400.0000 35697.6055
# 2021-05-29      NaN      NaN      NaN      NaN           NaN 34616.0664
# 2021-05-30      NaN      NaN      NaN      NaN           NaN 35678.1289
#
# ...

# %%
df["EURUSD=X"]
# Out:
# Price       Close   High    Low   Open  Volume
# Date
# 2014-10-01 1.2628 1.2640 1.2586 1.2629  0.0000
# 2014-10-02 1.2624 1.2691 1.2616 1.2625  0.0000
# 2014-10-03 1.2671 1.2670 1.2502 1.2670  0.0000
# 2014-10-04    NaN    NaN    NaN    NaN     NaN
# 2014-10-05    NaN    NaN    NaN    NaN     NaN
# ...           ...    ...    ...    ...     ...
# 2021-05-26 1.2249 1.2265 1.2200 1.2249  0.0000
# 2021-05-27 1.2193 1.2217 1.2176 1.2190  0.0000
# 2021-05-28 1.2193 1.2201 1.2133 1.2193  0.0000
# 2021-05-29    NaN    NaN    NaN    NaN     NaN
# 2021-05-30    NaN    NaN    NaN    NaN     NaN
#
# [2434 rows x 5 columns]

# %%
df["BTC-USD"]
# Out:
# Price           Close       High        Low       Open       Volume
# Date
# 2014-10-01   383.6150   391.3790   380.7800   387.4270     26229400
# 2014-10-02   375.0720   385.4970   372.9460   383.9880     21777700
# 2014-10-03   359.5120   377.6950   357.8590   375.1810     30901200
# 2014-10-04   328.8660   364.4870   325.8860   359.8920     47236500
# 2014-10-05   320.5100   341.8010   289.2960   328.9160     83308096
# ...               ...        ...        ...        ...          ...
# 2021-05-26 39294.1992 40782.0781 37905.8359 38392.6250  51346735160
# 2021-05-27 38436.9688 40379.6172 37247.9023 39316.8906  43210968721
# 2021-05-28 35697.6055 38856.9688 34779.0391 38507.0820  55200191952
# 2021-05-29 34616.0664 37234.5000 33693.9297 35684.1562  45231013335
# 2021-05-30 35678.1289 36400.6680 33520.7383 34607.4062  31646080921
#
# [2434 rows x 5 columns]

# %%
 df=df.swaplevel(axis="columns").sort_index(axis="columns")
 df
# Out:
# Price         Close                                                    \
# Ticker           BA    BTC-USD EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01 108.4067   383.6150   1.2628 1214.6000  39.0886 16804.7109
# 2014-10-02 107.9719   375.0720   1.2624 1214.2000  38.9694 16801.0508
# 2014-10-03 109.8762   359.5120   1.2671 1192.2000  39.2504 17009.6895
# 2014-10-04      NaN   328.8660      NaN       NaN      NaN        NaN
# 2014-10-05      NaN   320.5100      NaN       NaN      NaN        NaN
# ...             ...        ...      ...       ...      ...        ...
# 2021-05-26 241.3700 39294.1992   1.2249 1901.3000 243.7286 34323.0508
# 2021-05-27 250.7000 38436.9688   1.2193 1895.7000 241.6159 34464.6406
# 2021-05-28 247.0200 35697.6055   1.2193 1902.5000 241.9745 34529.4492
# 2021-05-29      NaN 34616.0664      NaN       NaN      NaN        NaN
# 2021-05-30      NaN 35678.1289      NaN       NaN      NaN        NaN
#
# ...

# %%
close = df.Close.copy()
close
# Out:
# Ticker           BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01 108.4067   383.6150    1.2628 1214.6000  39.0886 16804.7109
# 2014-10-02 107.9719   375.0720    1.2624 1214.2000  38.9694 16801.0508
# 2014-10-03 109.8762   359.5120    1.2671 1192.2000  39.2504 17009.6895
# 2014-10-04      NaN   328.8660       NaN       NaN      NaN        NaN
# 2014-10-05      NaN   320.5100       NaN       NaN      NaN        NaN
# ...             ...        ...       ...       ...      ...        ...
# 2021-05-26 241.3700 39294.1992    1.2249 1901.3000 243.7286 34323.0508
# 2021-05-27 250.7000 38436.9688    1.2193 1895.7000 241.6159 34464.6406
# 2021-05-28 247.0200 35697.6055    1.2193 1902.5000 241.9745 34529.4492
# 2021-05-29      NaN 34616.0664       NaN       NaN      NaN        NaN
# 2021-05-30      NaN 35678.1289       NaN       NaN      NaN        NaN
#
# [2434 rows x 6 columns]

# %%
close.describe()
# Out:
# Ticker        BA    BTC-USD  EURUSD=X      GC=F      MSFT       ^DJI
# count  1677.0000  2434.0000 1735.0000 1674.0000 1677.0000  1677.0000
# mean    219.2253  7613.8314    1.1406 1372.0145   99.6609 23004.3727
# std      95.5639 11611.1824    0.0501  235.7154   60.0870  4659.9220
# min      95.0100   178.1030    1.0390 1050.8000   34.6218 15660.1797
# 25%     128.9100   534.6280    1.1054 1216.5500   48.4541 18086.4004
# 50%     185.1009  4368.3750    1.1300 1283.1500   83.1176 23625.3398
# 75%     326.2300  9205.5750    1.1777 1482.3000  132.0357 26289.9805
# max     430.3000 63503.4570    1.2822 2051.5000  253.3002 34777.7617

# %%
close.BA.dropna().plot(figsize=(15,8),fontsize=13)
plt.legend(fontsize=13)
plt.show()

# %%
close.dropna().plot(figsize=(15,8),fontsize=13)
plt.legend(fontsize=13)
plt.show()
