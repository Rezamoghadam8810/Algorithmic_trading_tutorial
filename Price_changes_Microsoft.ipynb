# %% [markdown]
# <a href="https://colab.research.google.com/github/Rezamoghadam8810/Algorithmic_trading_tutorial/blob/main/Price_changes_Microsoft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use('ggplot')

# %%
close = pd.read_csv("/content/close.csv", index_col="Date", parse_dates=["Date"])
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01 108.4067   383.6150    1.2628 1214.6000  39.0886 16804.7109
# 2014-10-02 107.9719   375.0720    1.2624 1214.2000  38.9694 16801.0508
# 2014-10-03 109.8762   359.5120    1.2671 1192.2000  39.2504 17009.6895
# 2014-10-04      NaN   328.8660       NaN       NaN      NaN        NaN
# 2014-10-05      NaN   320.5100       NaN       NaN      NaN        NaN
# ...             ...        ...       ...       ...      ...        ...
# 2021-05-26 241.3700 39294.1992    1.2249 1901.3000 243.7286 34323.0508
# 2021-05-27 250.7000 38436.9688    1.2193 1895.7000 241.6159 34464.6406
# 2021-05-28 247.0200 35697.6055    1.2193 1902.5000 241.9745 34529.4492
# 2021-05-29      NaN 34616.0664       NaN       NaN      NaN        NaN
# 2021-05-30      NaN 35678.1289       NaN       NaN      NaN        NaN
#
# [2434 rows x 6 columns]

# %%
msft=close.MSFT.dropna().to_frame().copy()

# %%
msft
# Out:
#                MSFT
# Date
# 2014-10-01  39.0886
# 2014-10-02  38.9694
# 2014-10-03  39.2504
# 2014-10-06  39.2504
# 2014-10-07  38.7735
# ...             ...
# 2021-05-24 243.0405
# 2021-05-25 243.9515
# 2021-05-26 243.7286
# 2021-05-27 241.6159
# 2021-05-28 241.9745
#
# [1677 rows x 1 columns]

# %%
msft.rename(columns={"MSFT":"Price"}, inplace=True)

# %%
msft
# Out:
#               Price
# Date
# 2014-10-01  39.0886
# 2014-10-02  38.9694
# 2014-10-03  39.2504
# 2014-10-06  39.2504
# 2014-10-07  38.7735
# ...             ...
# 2021-05-24 243.0405
# 2021-05-25 243.9515
# 2021-05-26 243.7286
# 2021-05-27 241.6159
# 2021-05-28 241.9745
#
# [1677 rows x 1 columns]

# %%
msft.shift(periods=1)
# Out:
#               Price
# Date
# 2014-10-01      NaN
# 2014-10-02  39.0886
# 2014-10-03  38.9694
# 2014-10-06  39.2504
# 2014-10-07  39.2504
# ...             ...
# 2021-05-24 237.6036
# 2021-05-25 243.0405
# 2021-05-26 243.9515
# 2021-05-27 243.7286
# 2021-05-28 241.6159
#
# [1677 rows x 1 columns]

# %%
msft["P_lag1"]=msft.shift(periods=1)
msft
# Out:
#               Price   P_lag1
# Date
# 2014-10-01  39.0886      NaN
# 2014-10-02  38.9694  39.0886
# 2014-10-03  39.2504  38.9694
# 2014-10-06  39.2504  39.2504
# 2014-10-07  38.7735  39.2504
# ...             ...      ...
# 2021-05-24 243.0405 237.6036
# 2021-05-25 243.9515 243.0405
# 2021-05-26 243.7286 243.9515
# 2021-05-27 241.6159 243.7286
# 2021-05-28 241.9745 241.6159
#
# [1677 rows x 2 columns]

# %%
msft["P_diff"]=msft.Price.sub(msft.P_lag1)

# %%
msft
# Out:
#               Price   P_lag1  P_diff
# Date
# 2014-10-01  39.0886      NaN     NaN
# 2014-10-02  38.9694  39.0886 -0.1192
# 2014-10-03  39.2504  38.9694  0.2810
# 2014-10-06  39.2504  39.2504  0.0000
# 2014-10-07  38.7735  39.2504 -0.4769
# ...             ...      ...     ...
# 2021-05-24 243.0405 237.6036  5.4368
# 2021-05-25 243.9515 243.0405  0.9110
# 2021-05-26 243.7286 243.9515 -0.2229
# 2021-05-27 241.6159 243.7286 -2.1127
# 2021-05-28 241.9745 241.6159  0.3586
#
# [1677 rows x 3 columns]

# %%
msft["P_diff2"]=msft.Price.diff(periods=1)

# %%
msft
# Out:
#               Price   P_lag1  P_diff  P_diff2
# Date
# 2014-10-01  39.0886      NaN     NaN      NaN
# 2014-10-02  38.9694  39.0886 -0.1192  -0.1192
# 2014-10-03  39.2504  38.9694  0.2810   0.2810
# 2014-10-06  39.2504  39.2504  0.0000   0.0000
# 2014-10-07  38.7735  39.2504 -0.4769  -0.4769
# ...             ...      ...     ...      ...
# 2021-05-24 243.0405 237.6036  5.4368   5.4368
# 2021-05-25 243.9515 243.0405  0.9110   0.9110
# 2021-05-26 243.7286 243.9515 -0.2229  -0.2229
# 2021-05-27 241.6159 243.7286 -2.1127  -2.1127
# 2021-05-28 241.9745 241.6159  0.3586   0.3586
#
# [1677 rows x 4 columns]

# %%
msft.P_diff.equals(msft.P_diff2)
# Out:
# True

# %%
msft.Price.div(msft.P_lag1)-1
# Out:
# Date
# 2014-10-01       NaN
# 2014-10-02   -0.0031
# 2014-10-03    0.0072
# 2014-10-06    0.0000
# 2014-10-07   -0.0122
#                ...
# 2021-05-24    0.0229
# 2021-05-25    0.0037
# 2021-05-26   -0.0009
# 2021-05-27   -0.0087
# 2021-05-28    0.0015
# Length: 1677, dtype: float64

# %%
msft["Returns"]=msft.Price.pct_change(periods=1)
msft
# Out:
#               Price   P_lag1  P_diff  P_diff2  Returns
# Date
# 2014-10-01  39.0886      NaN     NaN      NaN      NaN
# 2014-10-02  38.9694  39.0886 -0.1192  -0.1192  -0.0031
# 2014-10-03  39.2504  38.9694  0.2810   0.2810   0.0072
# 2014-10-06  39.2504  39.2504  0.0000   0.0000   0.0000
# 2014-10-07  38.7735  39.2504 -0.4769  -0.4769  -0.0122
# ...             ...      ...     ...      ...      ...
# 2021-05-24 243.0405 237.6036  5.4368   5.4368   0.0229
# 2021-05-25 243.9515 243.0405  0.9110   0.9110   0.0037
# 2021-05-26 243.7286 243.9515 -0.2229  -0.2229  -0.0009
# 2021-05-27 241.6159 243.7286 -2.1127  -2.1127  -0.0087
# 2021-05-28 241.9745 241.6159  0.3586   0.3586   0.0015
#
# [1677 rows x 5 columns]

# %%
msft.drop(columns=["P_lag1", "P_diff","P_diff2"], inplace=True)

# %%
msft
# Out:
#               Price  Returns
# Date
# 2014-10-01  39.0886      NaN
# 2014-10-02  38.9694  -0.0031
# 2014-10-03  39.2504   0.0072
# 2014-10-06  39.2504   0.0000
# 2014-10-07  38.7735  -0.0122
# ...             ...      ...
# 2021-05-24 243.0405   0.0229
# 2021-05-25 243.9515   0.0037
# 2021-05-26 243.7286  -0.0009
# 2021-05-27 241.6159  -0.0087
# 2021-05-28 241.9745   0.0015
#
# [1677 rows x 2 columns]

# %%
msft.to_csv("msft.csv")
