# %% [markdown]
# <a href="https://colab.research.google.com/github/Rezamoghadam8810/Algorithmic_trading_tutorial/blob/main/Coding_challenge_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pip install yfinance

# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf
pd.options.display.float_format = '{:.4f}'.format
plt.style.use('ggplot')

# %%
start = "2015-01-02"
end="2020-12-31"
symbol = ["GE","Reliance.NS"]

# %%
df= yf.download(symbol,start,end)
df
# Out:
# [*********************100%***********************]  2 of 2 completed
# Price         Close                 High                  Low              \
# Ticker           GE RELIANCE.NS       GE RELIANCE.NS       GE RELIANCE.NS
# Date
# 2015-01-02 102.9729    188.3044 104.6165    190.5372 102.1921    188.0386
# 2015-01-05 101.0827    186.2418 102.7674    189.4420 100.7540    185.8697
# 2015-01-06  98.9049    177.7893 100.9594    185.6358  98.3296    176.9175
# 2015-01-07  98.9460    181.6594 100.2198    182.6162  98.5351    177.9807
# 2015-01-08 100.1376    179.0545 100.1787    183.4881  99.1515    178.6505
# ...             ...         ...      ...         ...      ...         ...
# 2020-12-23  53.1145    875.8555  53.7014    879.2799  51.9407    865.4021
# 2020-12-24  52.0875    898.5197  53.0656    900.6148  51.9407    876.7792
# 2020-12-28  52.0386    902.6424  52.7233    909.2659  51.7451    899.0378
# 2020-12-29  51.6473    896.6722  52.6744    906.6975  51.5495    893.2928
# ...

# %%
close=df.Close.copy()
close
# Out:
# Ticker           GE  RELIANCE.NS
# Date
# 2015-01-02 102.9729     188.3044
# 2015-01-05 101.0827     186.2418
# 2015-01-06  98.9049     177.7893
# 2015-01-07  98.9460     181.6594
# 2015-01-08 100.1376     179.0545
# ...             ...          ...
# 2020-12-23  53.1145     875.8555
# 2020-12-24  52.0875     898.5197
# 2020-12-28  52.0386     902.6424
# 2020-12-29  51.6473     896.6722
# 2020-12-30  52.3809     899.1278
#
# [1552 rows x 2 columns]

# %%
close.GE.dropna().plot(figsize=(15,8), fontsize=13)
plt.legend(fontsize=13)
plt.show()
# Out:
# <ipython-input-9-b9317640271f>:1: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(fontsize=13)

# %%
close.dropna().plot(figsize=(15,8), fontsize=13)
plt.legend(fontsize=13)
plt.show()

# %%
norm= close.div(close.iloc[0]).mul(1)
norm
# Out:
# Ticker         GE  RELIANCE.NS
# Date
# 2015-01-02 1.0000       1.0000
# 2015-01-05 0.9816       0.9890
# 2015-01-06 0.9605       0.9442
# 2015-01-07 0.9609       0.9647
# 2015-01-08 0.9725       0.9509
# ...           ...          ...
# 2020-12-23 0.5158       4.6513
# 2020-12-24 0.5058       4.7716
# 2020-12-28 0.5054       4.7935
# 2020-12-29 0.5016       4.7618
# 2020-12-30 0.5087       4.7749
#
# [1552 rows x 2 columns]

# %%
norm.dropna().plot(figsize=(15,8), fontsize=13)
plt.legend(fontsize=13)
plt.show()
