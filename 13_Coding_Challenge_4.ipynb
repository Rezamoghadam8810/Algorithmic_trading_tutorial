# %% [markdown]
# <a href="https://colab.research.google.com/github/Rezamoghadam8810/Algorithmic_trading_tutorial/blob/main/13_Coding_Challenge_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.4f}'.format
plt.style.use('ggplot')

# %%
close = pd.read_csv("/content/close.csv", index_col="Date", parse_dates=["Date"])
close
# Out:
#                  BA    BTC-USD  EURUSD=X      GC=F     MSFT       ^DJI
# Date
# 2014-10-01 108.4067   383.6150    1.2628 1214.6000  39.0886 16804.7109
# 2014-10-02 107.9719   375.0720    1.2624 1214.2000  38.9694 16801.0508
# 2014-10-03 109.8762   359.5120    1.2671 1192.2000  39.2504 17009.6895
# 2014-10-04      NaN   328.8660       NaN       NaN      NaN        NaN
# 2014-10-05      NaN   320.5100       NaN       NaN      NaN        NaN
# ...             ...        ...       ...       ...      ...        ...
# 2021-05-26 241.3700 39294.1992    1.2249 1901.3000 243.7286 34323.0508
# 2021-05-27 250.7000 38436.9688    1.2193 1895.7000 241.6159 34464.6406
# 2021-05-28 247.0200 35697.6055    1.2193 1902.5000 241.9745 34529.4492
# 2021-05-29      NaN 34616.0664       NaN       NaN      NaN        NaN
# 2021-05-30      NaN 35678.1289       NaN       NaN      NaN        NaN
#
# [2434 rows x 6 columns]

# %%
BA=close.BA.dropna().to_frame().copy()
BA.rename(columns={'BA': 'Price'}, inplace=True)
BA
# Out:
#               Price
# Date
# 2014-10-01 108.4067
# 2014-10-02 107.9719
# 2014-10-03 109.8762
# 2014-10-06 109.7893
# 2014-10-07 107.2328
# ...             ...
# 2021-05-24 237.4400
# 2021-05-25 240.7400
# 2021-05-26 241.3700
# 2021-05-27 250.7000
# 2021-05-28 247.0200
#
# [1677 rows x 1 columns]

# %%
BA.shift(periods=1)
# Out:
#               Price
# Date
# 2014-10-01      NaN
# 2014-10-02 108.4067
# 2014-10-03 107.9719
# 2014-10-06 109.8762
# 2014-10-07 109.7893
# ...             ...
# 2021-05-24 234.8200
# 2021-05-25 237.4400
# 2021-05-26 240.7400
# 2021-05-27 241.3700
# 2021-05-28 250.7000
#
# [1677 rows x 1 columns]

# %%
BA["P_lag1"]=BA.shift(periods=1)
BA
# Out:
#               Price   P_lag1
# Date
# 2014-10-01 108.4067      NaN
# 2014-10-02 107.9719 108.4067
# 2014-10-03 109.8762 107.9719
# 2014-10-06 109.7893 109.8762
# 2014-10-07 107.2328 109.7893
# ...             ...      ...
# 2021-05-24 237.4400 234.8200
# 2021-05-25 240.7400 237.4400
# 2021-05-26 241.3700 240.7400
# 2021-05-27 250.7000 241.3700
# 2021-05-28 247.0200 250.7000
#
# [1677 rows x 2 columns]

# %%
BA["P_diff"]=BA.Price.sub(BA.P_lag1)

# %%
BA
# Out:
#               Price   P_lag1  P_diff
# Date
# 2014-10-01 108.4067      NaN     NaN
# 2014-10-02 107.9719 108.4067 -0.4348
# 2014-10-03 109.8762 107.9719  1.9043
# 2014-10-06 109.7893 109.8762 -0.0869
# 2014-10-07 107.2328 109.7893 -2.5565
# ...             ...      ...     ...
# 2021-05-24 237.4400 234.8200  2.6200
# 2021-05-25 240.7400 237.4400  3.3000
# 2021-05-26 241.3700 240.7400  0.6300
# 2021-05-27 250.7000 241.3700  9.3300
# 2021-05-28 247.0200 250.7000 -3.6800
#
# [1677 rows x 3 columns]

# %%
BA["P_diff2"]=BA.Price.diff(periods=1)

# %%
BA
# Out:
#               Price   P_lag1  P_diff  P_diff2
# Date
# 2014-10-01 108.4067      NaN     NaN      NaN
# 2014-10-02 107.9719 108.4067 -0.4348  -0.4348
# 2014-10-03 109.8762 107.9719  1.9043   1.9043
# 2014-10-06 109.7893 109.8762 -0.0869  -0.0869
# 2014-10-07 107.2328 109.7893 -2.5565  -2.5565
# ...             ...      ...     ...      ...
# 2021-05-24 237.4400 234.8200  2.6200   2.6200
# 2021-05-25 240.7400 237.4400  3.3000   3.3000
# 2021-05-26 241.3700 240.7400  0.6300   0.6300
# 2021-05-27 250.7000 241.3700  9.3300   9.3300
# 2021-05-28 247.0200 250.7000 -3.6800  -3.6800
#
# [1677 rows x 4 columns]

# %%
BA.P_diff.equals(BA.P_diff2)
# Out:
# True

# %%
BA.Price.div(BA.P_lag1)-1
# Out:
# Date
# 2014-10-01       NaN
# 2014-10-02   -0.0040
# 2014-10-03    0.0176
# 2014-10-06   -0.0008
# 2014-10-07   -0.0233
#                ...
# 2021-05-24    0.0112
# 2021-05-25    0.0139
# 2021-05-26    0.0026
# 2021-05-27    0.0387
# 2021-05-28   -0.0147
# Length: 1677, dtype: float64

# %%
BA["Returns"]=BA.Price.pct_change(periods=1)
BA
# Out:
#               Price   P_lag1  P_diff  P_diff2  Returns
# Date
# 2014-10-01 108.4067      NaN     NaN      NaN      NaN
# 2014-10-02 107.9719 108.4067 -0.4348  -0.4348  -0.0040
# 2014-10-03 109.8762 107.9719  1.9043   1.9043   0.0176
# 2014-10-06 109.7893 109.8762 -0.0869  -0.0869  -0.0008
# 2014-10-07 107.2328 109.7893 -2.5565  -2.5565  -0.0233
# ...             ...      ...     ...      ...      ...
# 2021-05-24 237.4400 234.8200  2.6200   2.6200   0.0112
# 2021-05-25 240.7400 237.4400  3.3000   3.3000   0.0139
# 2021-05-26 241.3700 240.7400  0.6300   0.6300   0.0026
# 2021-05-27 250.7000 241.3700  9.3300   9.3300   0.0387
# 2021-05-28 247.0200 250.7000 -3.6800  -3.6800  -0.0147
#
# [1677 rows x 5 columns]

# %%
BA.drop(columns=["P_lag1", "P_diff","P_diff2"], inplace=True)

# %%
BA
# Out:
#               Price  Returns
# Date
# 2014-10-01 108.4067      NaN
# 2014-10-02 107.9719  -0.0040
# 2014-10-03 109.8762   0.0176
# 2014-10-06 109.7893  -0.0008
# 2014-10-07 107.2328  -0.0233
# ...             ...      ...
# 2021-05-24 237.4400   0.0112
# 2021-05-25 240.7400   0.0139
# 2021-05-26 241.3700   0.0026
# 2021-05-27 250.7000   0.0387
# 2021-05-28 247.0200  -0.0147
#
# [1677 rows x 2 columns]

# %%
BA['log_ret']=np.log(BA.Price / BA.Price.shift())
BA
# Out:
#               Price  Returns  log_ret
# Date
# 2014-10-01 108.4067      NaN      NaN
# 2014-10-02 107.9719  -0.0040  -0.0040
# 2014-10-03 109.8762   0.0176   0.0175
# 2014-10-06 109.7893  -0.0008  -0.0008
# 2014-10-07 107.2328  -0.0233  -0.0236
# ...             ...      ...      ...
# 2021-05-24 237.4400   0.0112   0.0111
# 2021-05-25 240.7400   0.0139   0.0138
# 2021-05-26 241.3700   0.0026   0.0026
# 2021-05-27 250.7000   0.0387   0.0379
# 2021-05-28 247.0200  -0.0147  -0.0148
#
# [1677 rows x 3 columns]

# %%
BA.describe()
# Out:
#           Price   Returns   log_ret
# count 1677.0000 1676.0000 1676.0000
# mean   219.2253    0.0008    0.0005
# std     95.5639    0.0263    0.0263
# min     95.0100   -0.2385   -0.2724
# 25%    128.9100   -0.0091   -0.0091
# 50%    185.1009    0.0008    0.0008
# 75%    326.2300    0.0105    0.0105
# max    430.3000    0.2432    0.2177

# %%
mu = BA.log_ret.mean()
mu
# Out:
# np.float64(0.00049139596478892)

# %%
sigma=BA.log_ret.std()
sigma
# Out:
# 0.026320279816703613

# %% [markdown]
# **Investment Multiple**

# %%
BA.Returns.add(1).prod() # cpmpounding simple returns
# Out:
# np.float64(2.278641966967599)

# %%
np.exp(BA.log_ret.sum()) # sdding log returns
# Out:
# np.float64(2.278641966967602)

# %% [markdown]
# **Normalized Prices with Base 1**

# %%
BA.Returns.add(1).cumprod() # compounding simple returns
# Out:
# Date
# 2014-10-01      NaN
# 2014-10-02   0.9960
# 2014-10-03   1.0136
# 2014-10-06   1.0128
# 2014-10-07   0.9892
#               ...
# 2021-05-24   2.1903
# 2021-05-25   2.2207
# 2021-05-26   2.2265
# 2021-05-27   2.3126
# 2021-05-28   2.2786
# Name: Returns, Length: 1677, dtype: float64

# %%
np.exp(BA.log_ret.cumsum()) # adding log returns
# Out:
# Date
# 2014-10-01      NaN
# 2014-10-02   0.9960
# 2014-10-03   1.0136
# 2014-10-06   1.0128
# 2014-10-07   0.9892
#               ...
# 2021-05-24   2.1903
# 2021-05-25   2.2207
# 2021-05-26   2.2265
# 2021-05-27   2.3126
# 2021-05-28   2.2786
# Name: log_ret, Length: 1677, dtype: float64

# %%
BA.log_ret.cumsum().apply(np.exp) # adding log returns
# Out:
# Date
# 2014-10-01      NaN
# 2014-10-02   0.9960
# 2014-10-03   1.0136
# 2014-10-06   1.0128
# 2014-10-07   0.9892
#               ...
# 2021-05-24   2.1903
# 2021-05-25   2.2207
# 2021-05-26   2.2265
# 2021-05-27   2.3126
# 2021-05-28   2.2786
# Name: log_ret, Length: 1677, dtype: float64

# %% [markdown]
# **CAGR**

# %%
(BA.Price[-1]/BA.Price[0])**(1/((BA.index[-1] - BA.index[0]).days / 365.25)) -1
# Out:
# <ipython-input-43-b6d82a356e96>:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   (BA.Price[-1]/BA.Price[0])**(1/((BA.index[-1] - BA.index[0]).days / 365.25)) -1
# np.float64(0.1317218283326278)

# %%
trading_days_year = BA.Returns.count() / ((BA.index[-1] - BA.index[0]).days / 365.25)
trading_days_year
# Out:
# np.float64(251.81365693130397)

# %%
np.exp(BA.log_ret.mean() * trading_days_year) - 1 # correct with mean of dayly log returns
# Out:
# np.float64(0.13172182833262802)
